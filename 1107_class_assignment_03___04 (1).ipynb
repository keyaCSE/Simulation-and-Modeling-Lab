# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Class Work

# %% [markdown]
# 1.

# %%
# Generate 100,000 random numbers in [0,1)
random_numbers = np.random.rand(10)

# Plot the histogram
plt.hist(random_numbers, bins=5,  alpha=0.5, color='blue', edgecolor='white')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Uniformly Distributed Random Numbers')
plt.grid(                                                                                                                                                                                                                                                              )

# Show the plot
plt.show()

# %% [markdown]
# 2

# %%
# Generate 500 random values from a normal distribution with mean=0 and std=0
NormalValues = np.random.normal(0, 1, 500)

# Create a histogram
plt.hist(NormalValues, bins=13, edgecolor='black')
plt.title('Histogram of Normal Distribution (mean=0, std=1)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# LAB Assignment 02

# %%
non_seeded_matrix = np.random.randint(1, 50, (3, 3))
print("\nNon-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Non-Seeded Random Matrix:
#  [[ 4 26 43]
#  [10 46 49]
#  [ 7 26 20]]

# %%
# With Seed
np.random.seed(10)  # Setting seed to 10
seeded_matrix = np.random.randint(1, 50, (3, 3))
print("Seeded Random Matrix:\n", seeded_matrix)

# Without Seed
np.random.seed(None)  # No seed, generates different values each time
non_seeded_matrix = np.random.randint(1, 50, (3, 3))
print("\nNon-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Seeded Random Matrix:
#  [[10 37 16]
#  [ 1 29 26]
#  [30 49 30]]
#
# Non-Seeded Random Matrix:
#  [[33 39 33]
#  [47  9 34]
#  [40 33 23]]

# %% [markdown]
# Observation: here, seeded random matrix is fixed after generation and non-seeded matrix changes randomly in every generation

# %% [markdown]
# Task Part 01

# %%
import random  # to create random numbers

def estimate_pi(num_points):
    inside = 0  # how many points inside the circle

    for _ in range(num_points):
        x = random.random()  # pick a random number from 0 to 1
        y = random.random()
        if x*x + y*y <= 10*10:
            inside += 1  # it's inside the circle

    pi = (400 * inside )/ (100 * num_points)
    print("Estimated pi for", num_points, "points is:", pi)

# Try this with different number of points
estimate_pi(3200) #(200*16)yeasminkabirkeya
# Out:
# Estimated pi for 3200 points is: 4.0
